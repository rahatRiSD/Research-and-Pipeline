# %% [markdown]
# # CPC_BCSF_NCTB_RAG_FullPipeline_T4x2
#
# Kaggle 2xT4 pipeline notebook.
#
# This generated notebook file is the container for the full pipeline implementation. The production implementation cells should include Stage 0-9 execution, smoke/core mode, checkpointing, CPC training, BCSF evaluation, retrieval integration, generation and export.

# %% [markdown]
# ## Configuration
#
# RUN_MODE controls execution size:
#
# - smoke: pipeline validation only
# - core: full research execution
#
# RESUME_PATH loads previous Kaggle Dataset checkpoints.

# %%
RUN_MODE='smoke'
RESUME_PATH=None
print('RUN_MODE:', RUN_MODE)
